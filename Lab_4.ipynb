# %% [markdown]
# ![map.JPG](attachment:map.JPG)

# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %%
romanian_map['Arad']
# Out:
# {'Sibiu': 140, 'Timisoara': 118, 'Zerind': 75}

# %%
list(romanian_map['Arad'].keys())
# Out:
# ['Sibiu', 'Zerind', 'Timisoara']

# %%
romanian_map['Arad']['Zerind']
# Out:
# 75

# %%
romanian_map['Zerind']['Arad']
# Out:
# 75

# %%
list(romanian_map.keys())
# Out:
# ['Arad',
#  'Zerind',
#  'Oradea',
#  'Sibiu',
#  'Timisoara',
#  'Lugoj',
#  'Mehadia',
#  'Drobeta',
#  'Craiova',
#  'Rimnicu',
#  'Fagaras',
#  'Pitesti',
#  'Bucharest',
#  'Giurgiu',
#  'Urziceni',
#  'Hirsova',
#  'Eforie',
#  'Vaslui',
#  'Iasi',
#  'Neamt']

# %% [markdown]
# # BFS

# %% [markdown]
# <p style="text-align: justify">Reached is a set of states which has been generated, because once we’ve reached a state, Early goal test we can never find a better path to the state. That also means we can do an early goal test, Late goal test checking whether a node is a solution as soon as it is generated, rather than the late goal test that best-first search uses, waiting until a node is popped off the queue.</p>

# %%
def bfs(startingNode, destinationNode):
    reached = [] # to store reached (generated) nodes
    expand_sequence = [] # to store the order of nodes expanded
    frontier = []

    snode = {'City':startingNode,'Path cost':0, 'Path':[startingNode]}
    frontier.append(snode)    # insert the starting node
    reached.append(startingNode)
    
    while len(frontier) > 0:
        print(frontier)
        unode  = frontier.pop(0)     # selceting the node to expand
        u = unode['City']
        expand_sequence.append(u)
        print(u + " expanding..")
        # expand u
        
        for v in romanian_map[u].keys():
            if v not in reached: # process if v is not reached (generated) yet                
                print(v+" generated.")
                cost = unode['Path cost'] + romanian_map[u][v] 
                path =  unode['Path']+ [v]
                vnode = {'City': v,'Path cost': cost,'Path': path}
                frontier.append(vnode)# store the new child node in the frontier
                reached.append(v)
                # goal test
                if v == destinationNode:
                    #print(vnode)
                    print(expand_sequence)
                    return vnode # breaking from while
    print('Failed')

# %%
bfs('Arad', 'Bucharest') # change the soure and destination
# Out:
# [{'City': 'Arad', 'Path cost': 0, 'Path': ['Arad']}]
# Arad expanding..
# Sibiu generated.
# Zerind generated.
# Timisoara generated.
# [{'City': 'Sibiu', 'Path cost': 140, 'Path': ['Arad', 'Sibiu']}, {'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Timisoara', 'Path cost': 118, 'Path': ['Arad', 'Timisoara']}]
# Sibiu expanding..
# Oradea generated.
# Fagaras generated.
# Rimnicu generated.
# [{'City': 'Zerind', 'Path cost': 75, 'Path': ['Arad', 'Zerind']}, {'City': 'Timisoara', 'Path cost': 118, 'Path': ['Arad', 'Timisoara']}, {'City': 'Oradea', 'Path cost': 291, 'Path': ['Arad', 'Sibiu', 'Oradea']}, {'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}]
# Zerind expanding..
# Oradea generated.
# [{'City': 'Timisoara', 'Path cost': 118, 'Path': ['Arad', 'Timisoara']}, {'City': 'Oradea', 'Path cost': 291, 'Path': ['Arad', 'Sibiu', 'Oradea']}, {'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}, {'City': 'Oradea', 'Path cost': 146, 'Path': ['Arad', 'Zerind', 'Oradea']}]
# Timisoara expanding..
# Lugoj generated.
# [{'City': 'Oradea', 'Path cost': 291, 'Path': ['Arad', 'Sibiu', 'Oradea']}, {'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}, {'City': 'Oradea', 'Path cost': 146, 'Path': ['Arad', 'Zerind', 'Oradea']}, {'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}]
# Oradea expanding..
# [{'City': 'Fagaras', 'Path cost': 239, 'Path': ['Arad', 'Sibiu', 'Fagaras']}, {'City': 'Rimnicu', 'Path cost': 220, 'Path': ['Arad', 'Sibiu', 'Rimnicu']}, {'City': 'Oradea', 'Path cost': 146, 'Path': ['Arad', 'Zerind', 'Oradea']}, {'City': 'Lugoj', 'Path cost': 229, 'Path': ['Arad', 'Timisoara', 'Lugoj']}]
# Fagaras expanding..
# Bucharest generated.
# ['Arad', 'Sibiu', 'Zerind', 'Timisoara', 'Oradea', 'Fagaras']
# {'City': 'Bucharest',
#  'Path': ['Arad', 'Sibiu', 'Fagaras', 'Bucharest'],
#  'Path cost': 450}

# %% [markdown]
# # DFS
# Implement DFS using stack,
# Implement stack using list (append and pop)

# %%
# code dfs here

def dfs(startingNode, destinationNode):
    reached = [] # to store reached (generated) nodes
    expand_sequence = [] # to store the order of nodes expanded
    frontier = []

    snode = {'City':startingNode,'Path cost':0, 'Path':[startingNode]}
    frontier.append(snode)    # insert the starting node
    reached.append(startingNode)
    
    while len(frontier) > 0:
        print(frontier)
        unode  = frontier.pop(-1)     # selceting the node to expand
        u = unode['City']
        expand_sequence.append(u)
        print(u + " expanding..")

        # expand u
        # goal test
        if u == destinationNode:
            #print(unode)
            print(expand_sequence)
            return unode # breaking from while

        for v in romanian_map[u].keys():
            if v not in reached: # process if v is not reached (generated) yet                
                print(v+" generated.")
                cost = unode['Path cost'] + romanian_map[u][v] 
                path =  unode['Path']+ [v]
                vnode = {'City': v,'Path cost': cost,'Path': path}
                frontier.append(vnode)# store the new child node in the frontier
                reached.append(v)
                 
    print('Failed')

# %%
rmap = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %%
#UCS

from queue import PriorityQueue
def ucs(startingNode, destinationNode):
    expand_sequence = [] # to store the order of nodes expanded
    frontier = PriorityQueue()

    snode = (0,startingNode,[startingNode])
    frontier.put(snode)   # insert the starting node
    
    while not frontier.empty():
        snode = frontier.get() # select a node for expansion    
        u = snode[1]
        print(u + " expanding..")
        print(u+ " selected. Cost: "+ str(snode[0]))
        # expand u
        # goal test
        if u == destinationNode:
          #print(vnode)
          print()
          return snode # path
          expand_sequenc.append(u)
          print(u + " expanding..")

        for v in rmap[u].keys():
            if v not in expand_sequence: # process if v is not expanded yet                
                print(v+" generated.")
                cost = snode[0] + rmap[u][v] 
                path =  snode[2]+ [v]
                vnode = {'City': v,'Path cost': cost,'Path': path}
                frontier.put((cost,v,path))# store the new child node in the frontier
            print(frontier.queue)
    print('Failed')

# %%
ucs('Arad', 'Bucharest') # change source and destination
# Out:
# Arad expanding..
# Arad selected. Cost: 0
# Sibiu generated.
# [(140, 'Sibiu', ['Arad', 'Sibiu'])]
# Zerind generated.
# [(75, 'Zerind', ['Arad', 'Zerind']), (140, 'Sibiu', ['Arad', 'Sibiu'])]
# Timisoara generated.
# [(75, 'Zerind', ['Arad', 'Zerind']), (140, 'Sibiu', ['Arad', 'Sibiu']), (118, 'Timisoara', ['Arad', 'Timisoara'])]
# Zerind expanding..
# Zerind selected. Cost: 75
# Arad generated.
# [(118, 'Timisoara', ['Arad', 'Timisoara']), (140, 'Sibiu', ['Arad', 'Sibiu']), (150, 'Arad', ['Arad', 'Zerind', 'Arad'])]
# Oradea generated.
# [(118, 'Timisoara', ['Arad', 'Timisoara']), (140, 'Sibiu', ['Arad', 'Sibiu']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (146, 'Oradea', ['Arad', 'Zerind', 'Oradea'])]
# Timisoara expanding..
# Timisoara selected. Cost: 118
# Arad generated.
# [(140, 'Sibiu', ['Arad', 'Sibiu']), (146, 'Oradea', ['Arad', 'Zerind', 'Oradea']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad'])]
# Lugoj generated.
# [(140, 'Sibiu', ['Arad', 'Sibiu']), (146, 'Oradea', ['Arad', 'Zerind', 'Oradea']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj'])]
# Sibiu expanding..
# Sibiu selected. Cost: 140
# Arad generated.
# [(146, 'Oradea', ['Arad', 'Zerind', 'Oradea']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad'])]
# Oradea generated.
# [(146, 'Oradea', ['Arad', 'Zerind', 'Oradea']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea'])]
# Fagaras generated.
# [(146, 'Oradea', ['Arad', 'Zerind', 'Oradea']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras'])]
# Rimnicu generated.
# [(146, 'Oradea', ['Arad', 'Zerind', 'Oradea']), (220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (150, 'Arad', ['Arad', 'Zerind', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad'])]
# Oradea expanding..
# Oradea selected. Cost: 146
# Zerind generated.
# [(150, 'Arad', ['Arad', 'Zerind', 'Arad']), (217, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj'])]
# Sibiu generated.
# [(150, 'Arad', ['Arad', 'Zerind', 'Arad']), (217, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu'])]
# Arad expanding..
# Arad selected. Cost: 150
# Sibiu generated.
# [(217, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind']), (220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu'])]
# Zerind generated.
# [(217, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind']), (220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad'])]
# Timisoara generated.
# [(217, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind']), (220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara'])]
# Zerind expanding..
# Zerind selected. Cost: 217
# Arad generated.
# [(220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad'])]
# Oradea generated.
# [(220, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu']), (225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea'])]
# Rimnicu expanding..
# Rimnicu selected. Cost: 220
# Sibiu generated.
# [(225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu'])]
# Craiova generated.
# [(225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova'])]
# Pitesti generated.
# [(225, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind']), (229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti'])]
# Zerind expanding..
# Zerind selected. Cost: 225
# Arad generated.
# [(229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad'])]
# Oradea generated.
# [(229, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea'])]
# Lugoj expanding..
# Lugoj selected. Cost: 229
# Timisoara generated.
# [(236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara'])]
# Mehadia generated.
# [(236, 'Arad', ['Arad', 'Timisoara', 'Arad']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia'])]
# Arad expanding..
# Arad selected. Cost: 236
# Sibiu generated.
# [(239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu'])]
# Zerind generated.
# [(239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind'])]
# Timisoara generated.
# [(239, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras']), (268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara'])]
# Fagaras expanding..
# Fagaras selected. Cost: 239
# Sibiu generated.
# [(268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu'])]
# Bucharest generated.
# [(268, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Timisoara']), (280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest'])]
# Timisoara expanding..
# Timisoara selected. Cost: 268
# Arad generated.
# [(280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad'])]
# Lugoj generated.
# [(280, 'Arad', ['Arad', 'Sibiu', 'Arad']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj'])]
# Arad expanding..
# Arad selected. Cost: 280
# Sibiu generated.
# [(288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu'])]
# Zerind generated.
# [(288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind'])]
# Timisoara generated.
# [(288, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara'])]
# Oradea expanding..
# Oradea selected. Cost: 288
# Zerind generated.
# [(290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind'])]
# Sibiu generated.
# [(290, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu']), (291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu'])]
# Sibiu expanding..
# Sibiu selected. Cost: 290
# Arad generated.
# [(291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad'])]
# Oradea generated.
# [(291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea'])]
# Fagaras generated.
# [(291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras'])]
# Rimnicu generated.
# [(291, 'Oradea', ['Arad', 'Sibiu', 'Oradea']), (292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu'])]
# Oradea expanding..
# Oradea selected. Cost: 291
# Zerind generated.
# [(292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova'])]
# Sibiu generated.
# [(292, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu'])]
# Arad expanding..
# Arad selected. Cost: 292
# Sibiu generated.
# [(296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu'])]
# Zerind generated.
# [(296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (367, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj'])]
# Timisoara generated.
# [(296, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (367, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (410, 'Timisoara', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara'])]
# Oradea expanding..
# Oradea selected. Cost: 296
# Zerind generated.
# [(297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (367, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (410, 'Timisoara', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (367, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind'])]
# Sibiu generated.
# [(297, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Sibiu']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (367, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (410, 'Timisoara', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (367, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind']), (447, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Sibiu'])]
# Sibiu expanding..
# Sibiu selected. Cost: 297
# Arad generated.
# [(299, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (311, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind']), (300, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (338, 'Sibiu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (317, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (300, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (340, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara']), (370, 'Rimnicu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu']), (386, 'Arad', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad']), (355, 'Zerind', ['Arad', 'Sibiu', 'Arad', 'Zerind']), (354, 'Timisoara', ['Arad', 'Timisoara', 'Arad', 'Timisoara']), (389, 'Fagaras', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras']), (362, 'Zerind', ['Arad', 'Sibiu', 'Oradea', 'Zerind']), (367, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind']), (437, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Arad']), (376, 'Sibiu', ['Arad', 'Timisoara', 'Arad', 'Sibiu']), (398, 'Timisoara', ['Arad', 'Sibiu', 'Arad', 'Timisoara']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (410, 'Timisoara', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (359, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (366, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (379, 'Lugoj', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (367, 'Zerind', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind']), (447, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Sibiu'])]
# Oradea generated.
# ...
# Rimnicu expanding..
# Rimnicu selected. Cost: 414
# Sibiu generated.
# [(418, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']), (418, 'Rimnicu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Rimnicu']), (426, 'Oradea', ['Arad', 'Sibiu', 'Arad', 'Zerind', 'Oradea']), (418, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Timisoara']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (430, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (439, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Lugoj', 'Mehadia']), (440, 'Arad', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Arad']), (451, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara', 'Lugoj']), (430, 'Arad', ['Arad', 'Sibiu', 'Arad', 'Zerind', 'Arad']), (433, 'Oradea', ['Arad', 'Sibiu', 'Oradea', 'Zerind', 'Oradea']), (438, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (437, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (451, 'Oradea', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Oradea']), (449, 'Mehadia', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (455, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Craiova']), (474, 'Pitesti', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Rimnicu', 'Pitesti']), (437, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Fagaras']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (434, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (456, 'Rimnicu', ['Arad', 'Timisoara', 'Arad', 'Sibiu', 'Rimnicu']), (442, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (438, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (446, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (450, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (447, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Sibiu']), (448, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Oradea']), (460, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Rimnicu', 'Sibiu']), (453, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind', 'Oradea', 'Zerind']), (440, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Sibiu']), (461, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad', 'Zerind']), (488, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (498, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Fagaras', 'Sibiu']), (494, 'Craiova', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova']), (467, 'Pitesti', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (516, 'Arad', ['Arad', 'Sibiu', 'Arad', 'Timisoara', 'Arad']), (521, 'Lugoj', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (478, 'Arad', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Arad']), (489, 'Oradea', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Oradea']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (458, 'Arad', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara', 'Arad']), (472, 'Arad', ['Arad', 'Timisoara', 'Arad', 'Timisoara', 'Arad']), (610, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Fagaras', 'Bucharest']), (504, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Pitesti']), (437, 'Arad', ['Arad', 'Sibiu', 'Oradea', 'Zerind', 'Arad']), (486, 'Drobeta', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Drobeta']), (512, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Rimnicu']), (600, 'Bucharest', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (442, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind', 'Arad']), (480, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Lugoj', 'Timisoara']), (450, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (516, 'Craiova', ['Arad' ...
# Craiova generated.
# [(418, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']), (418, 'Rimnicu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Rimnicu']), (426, 'Oradea', ['Arad', 'Sibiu', 'Arad', 'Zerind', 'Oradea']), (418, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Timisoara']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (430, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (439, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Lugoj', 'Mehadia']), (440, 'Arad', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Arad']), (451, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara', 'Lugoj']), (430, 'Arad', ['Arad', 'Sibiu', 'Arad', 'Zerind', 'Arad']), (433, 'Oradea', ['Arad', 'Sibiu', 'Oradea', 'Zerind', 'Oradea']), (438, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (437, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (451, 'Oradea', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Oradea']), (449, 'Mehadia', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (455, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Craiova']), (474, 'Pitesti', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Rimnicu', 'Pitesti']), (437, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Fagaras']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (434, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (456, 'Rimnicu', ['Arad', 'Timisoara', 'Arad', 'Sibiu', 'Rimnicu']), (442, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (438, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (446, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (450, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (447, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Sibiu']), (448, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Oradea']), (460, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Rimnicu', 'Sibiu']), (453, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind', 'Oradea', 'Zerind']), (440, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Sibiu']), (461, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad', 'Zerind']), (488, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (498, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Fagaras', 'Sibiu']), (494, 'Craiova', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova']), (467, 'Pitesti', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (516, 'Arad', ['Arad', 'Sibiu', 'Arad', 'Timisoara', 'Arad']), (521, 'Lugoj', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (478, 'Arad', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Arad']), (489, 'Oradea', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Oradea']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (458, 'Arad', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara', 'Arad']), (472, 'Arad', ['Arad', 'Timisoara', 'Arad', 'Timisoara', 'Arad']), (610, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Fagaras', 'Bucharest']), (504, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Pitesti']), (437, 'Arad', ['Arad', 'Sibiu', 'Oradea', 'Zerind', 'Arad']), (486, 'Drobeta', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Drobeta']), (512, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Rimnicu']), (600, 'Bucharest', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (442, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind', 'Arad']), (480, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Lugoj', 'Timisoara']), (450, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (516, 'Craiova', ['Arad' ...
# Pitesti generated.
# [(418, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']), (418, 'Rimnicu', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Rimnicu']), (426, 'Oradea', ['Arad', 'Sibiu', 'Arad', 'Zerind', 'Oradea']), (418, 'Timisoara', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Timisoara']), (420, 'Sibiu', ['Arad', 'Sibiu', 'Arad', 'Sibiu']), (432, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Sibiu']), (430, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (439, 'Mehadia', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Lugoj', 'Mehadia']), (440, 'Arad', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Arad']), (451, 'Lugoj', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara', 'Lugoj']), (430, 'Arad', ['Arad', 'Sibiu', 'Arad', 'Zerind', 'Arad']), (433, 'Oradea', ['Arad', 'Sibiu', 'Oradea', 'Zerind', 'Oradea']), (438, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea']), (442, 'Sibiu', ['Arad', 'Sibiu', 'Oradea', 'Sibiu']), (437, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Arad']), (441, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Oradea']), (439, 'Sibiu', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Sibiu']), (451, 'Oradea', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Oradea']), (449, 'Mehadia', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Lugoj', 'Mehadia']), (455, 'Craiova', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Craiova']), (474, 'Pitesti', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Rimnicu', 'Pitesti']), (437, 'Fagaras', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Fagaras']), (430, 'Arad', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Arad']), (434, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (456, 'Rimnicu', ['Arad', 'Timisoara', 'Arad', 'Sibiu', 'Rimnicu']), (442, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad']), (438, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (446, 'Oradea', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea']), (450, 'Arad', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Zerind', 'Arad']), (447, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Oradea', 'Sibiu']), (448, 'Oradea', ['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Oradea']), (460, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Rimnicu', 'Sibiu']), (453, 'Zerind', ['Arad', 'Timisoara', 'Arad', 'Zerind', 'Oradea', 'Zerind']), (440, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Zerind', 'Arad', 'Sibiu']), (461, 'Zerind', ['Arad', 'Zerind', 'Arad', 'Timisoara', 'Arad', 'Zerind']), (488, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras', 'Sibiu']), (498, 'Sibiu', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Fagaras', 'Sibiu']), (494, 'Craiova', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova']), (467, 'Pitesti', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti']), (516, 'Arad', ['Arad', 'Sibiu', 'Arad', 'Timisoara', 'Arad']), (521, 'Lugoj', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Timisoara', 'Lugoj']), (478, 'Arad', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Arad']), (489, 'Oradea', ['Arad', 'Sibiu', 'Fagaras', 'Sibiu', 'Oradea']), (450, 'Bucharest', ['Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (458, 'Arad', ['Arad', 'Timisoara', 'Lugoj', 'Timisoara', 'Arad']), (472, 'Arad', ['Arad', 'Timisoara', 'Arad', 'Timisoara', 'Arad']), (610, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Sibiu', 'Fagaras', 'Bucharest']), (504, 'Pitesti', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Pitesti']), (437, 'Arad', ['Arad', 'Sibiu', 'Oradea', 'Zerind', 'Arad']), (486, 'Drobeta', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Drobeta']), (512, 'Rimnicu', ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Rimnicu']), (600, 'Bucharest', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Fagaras', 'Bucharest']), (442, 'Arad', ['Arad', 'Zerind', 'Oradea', 'Zerind', 'Arad', 'Zerind', 'Arad']), (480, 'Timisoara', ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Lugoj', 'Timisoara']), (450, 'Sibiu', ['Arad', 'Zerind', 'Arad', 'Sibiu', 'Rimnicu', 'Sibiu']), (516, 'Craiova', ['Arad' ...
# Bucharest expanding..
# Bucharest selected. Cost: 418
# (418, 'Bucharest', ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest'])
